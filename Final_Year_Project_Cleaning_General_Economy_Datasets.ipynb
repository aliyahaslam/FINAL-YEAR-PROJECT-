# %% [markdown]
# <a href="https://colab.research.google.com/github/aliyahaslam/FINAL-YEAR-PROJECT-/blob/main/Final_Year_Project_Cleaning_General_Economy_Datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
uk_economy = pd.read_csv('/content/GENERAL ECONOMY DATASET .csv')
uk_economy.head()
# Out:
#     DATE   INFLATION RATE    DATE  UNEMPLOYMENT RATE  Quarter   \
# 0  2018.0             2.3  2018.0                 4.2  2018 Q1
# 1  2019.0             1.7  2019.0                 3.9  2018 Q2
# 2  2020.0             1.0  2020.0                 4.7  2018 Q3
# 3  2021.0             2.5  2021.0                 4.6  2018 Q4
# 4  2022.0             7.9  2022.0                 3.9  2019 Q1
#
#    INFLATION RATE  Quarter .1  UNEMPLOYMENT RATE .1     MONTH  \
# 0              2.5    2018 Q1                   4.3  2018 JAN
# 1              2.2    2018 Q2                   4.1  2018 FEB
# 2              2.3    2018 Q3                   4.2  2018 MAR
# 3              2.1    2018 Q4                   4.1  2018 APR
# 4              1.8    2019 Q1                   3.9  2018 MAY
#
#    INFLATION RATE.1   MONTH.1  UNEMPLOYMENT RATE .2
# 0               2.7  2018 JAN                   4.3
# 1               2.5  2018 FEB                   4.3
# 2               2.3  2018 MAR                   4.3
# ...

# %%
uk_economy.shape
# Out:
# (72, 12)

# %%
uk_economy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   DATE                  6 non-null      float64
#  1   INFLATION RATE        6 non-null      float64
#  2   DATE                  6 non-null      float64
#  3   UNEMPLOYMENT RATE     6 non-null      float64
#  4   Quarter               24 non-null     object
#  5   INFLATION RATE        24 non-null     float64
#  6   Quarter .1            24 non-null     object
#  7   UNEMPLOYMENT RATE .1  24 non-null     float64
#  8   MONTH                 72 non-null     object
#  9   INFLATION RATE.1      72 non-null     float64
#  10  MONTH.1               72 non-null     object
#  11  UNEMPLOYMENT RATE .2  72 non-null     float64
# dtypes: float64(8), object(4)
# memory usage: 6.9+ KB

# %%
uk_economy.describe()
# Out:
#              DATE   INFLATION RATE         DATE  UNEMPLOYMENT RATE   \
# count     6.000000        6.000000     6.000000            6.000000
# mean   2020.500000        3.700000  2020.500000            4.216667
# std       1.870829        2.896204     1.870829            0.354495
# min    2018.000000        1.000000  2018.000000            3.900000
# 25%    2019.250000        1.850000  2019.250000            3.925000
# 50%    2020.500000        2.400000  2020.500000            4.100000
# 75%    2021.750000        5.725000  2021.750000            4.500000
# max    2023.000000        7.900000  2023.000000            4.700000
#
#        INFLATION RATE   UNEMPLOYMENT RATE .1  INFLATION RATE.1  \
# count        24.000000             24.000000         72.000000
# mean          3.716667              4.212500          3.712500
# std           2.907512              0.419433          2.880431
# min           0.800000              3.800000          0.500000
# ...

# %%
usa_economy = pd.read_csv('/content/USA General Economy.csv')
usa_economy.head()
# Out:
#       Month  Year  Consumer Confidence Index TX  \
# 0   JANUARY  2018                         151.0
# 1  FEBRUARY  2018                         154.7
# 2     MARCH  2018                         139.2
# 3     APRIL  2018                         141.5
# 4       MAY  2018                         147.3
#
#    Consumer Confidence West South Central  Consumer Confidence Index US  \
# 0                                   142.3                         124.3
# 1                                   144.9                         130.0
# 2                                   129.7                         127.0
# 3                                   135.4                         125.6
# 4                                   141.1                         128.8
#
#    PCE Deflator  Consumer Price Index TX  Consumer Price Index U.S.  \
# 0           NaN                  225.954                    247.867
# 1           NaN                  227.441                    248.991
# ...

# %%
usa_economy.shape
# Out:
# (72, 31)

# %%
usa_economy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 31 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Month                                   72 non-null     object
#  1   Year                                    72 non-null     int64
#  2   Consumer Confidence Index TX            72 non-null     float64
#  3   Consumer Confidence West South Central  72 non-null     float64
#  4   Consumer Confidence Index US            72 non-null     float64
#  5   PCE Deflator                            0 non-null      float64
#  6   Consumer Price Index TX                 72 non-null     float64
#  7   Consumer Price Index U.S.               72 non-null     float64
#  8   CPI U.S. Ex Food and Energy             0 non-null      float64
#  9   Nonfarm Employment TX                   72 non-null     float64
# ...

# %%
usa_economy.describe()
# Out:
#              Year  Consumer Confidence Index TX  \
# count    72.00000                     72.000000
# mean   2020.50000                    122.681944
# std       1.71981                     19.350513
# min    2018.00000                     86.900000
# 25%    2019.00000                    105.375000
# 50%    2020.50000                    120.250000
# 75%    2022.00000                    141.500000
# max    2023.00000                    154.700000
#
#        Consumer Confidence West South Central  Consumer Confidence Index US  \
# count                               72.000000                     72.000000
# mean                               116.334722                    113.681944
# std                                 18.260248                     14.597360
# min                                 84.400000                     85.700000
# 25%                                100.975000                    103.025000
# ...

# %%
usa_economy.isnull().sum()
# Out:
# Month                                      0
# Year                                       0
# Consumer Confidence Index TX               0
# Consumer Confidence West South Central     0
# Consumer Confidence Index US               0
# PCE Deflator                              72
# Consumer Price Index TX                    0
# Consumer Price Index U.S.                  0
# CPI U.S. Ex Food and Energy               72
# Nonfarm Employment TX                      0
# Nonfarm Employment U.S.                    0
# Unemployment TX                            0
# Unemployment U.S.                          0
# Single Family Building Permits TX          0
# Multi Family Building Permits TX           0
# Existing Single Family Home Sales TX       0
# Existing Single Family Home Price TX       0
# Non Residential Building Construction      0
# Total Sales Tax Collections Retail TX      0
# Total Sales Tax Collections TX             0
# Retail Gasoline Price TX                   0
# ...

# %%
usa_economy.dropna(inplace=True)
usa_economy.isnull().sum()
# Out:
# Month                                     0
# Year                                      0
# Consumer Confidence Index TX              0
# Consumer Confidence West South Central    0
# Consumer Confidence Index US              0
# PCE Deflator                              0
# Consumer Price Index TX                   0
# Consumer Price Index U.S.                 0
# CPI U.S. Ex Food and Energy               0
# Nonfarm Employment TX                     0
# Nonfarm Employment U.S.                   0
# Unemployment TX                           0
# Unemployment U.S.                         0
# Single Family Building Permits TX         0
# Multi Family Building Permits TX          0
# Existing Single Family Home Sales TX      0
# Existing Single Family Home Price TX      0
# Non Residential Building Construction     0
# Total Sales Tax Collections Retail TX     0
# Total Sales Tax Collections TX            0
# Retail Gasoline Price TX                  0
# ...

# %%
uk_public = pd.read_csv('/content/UK CLEAN PUBLIC SECTOR CR.csv')
uk_public.head()
# Out:
#                                            £ million  Unnamed: 1 2017 to 2018  \
# 0                                Income tax [note 1]         NaN      180,609
# 1                                  Capital gains tax         NaN        7,793
# 2  Miscellaneous taxes on income and wealth, of w...         NaN          789
# 3  Betting and gaming duty - taxes on income and ...         NaN          686
# 4                                              Other         NaN          103
#
#   2018 to 2019 2019 to 2020 2020 to 2021 2021 to 2022 2022 to 2023
# 0      192,505      192,537      195,263      224,779      250,490
# 1        9,191        9,827       11,131       15,267       16,928
# 2          754          664          799          759          786
# 3          652          578          708          653          681
# 4          102           86           91          106          105

# %%
uk_public.shape
# Out:
# (74, 8)

# %%
uk_public.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   £ million     74 non-null     object
#  1   Unnamed: 1    0 non-null      float64
#  2   2017 to 2018  74 non-null     object
#  3   2018 to 2019  74 non-null     object
#  4   2019 to 2020  74 non-null     object
#  5   2020 to 2021  74 non-null     object
#  6   2021 to 2022  74 non-null     object
#  7   2022 to 2023  74 non-null     object
# dtypes: float64(1), object(7)
# memory usage: 4.8+ KB

# %%
uk_public.describe()
# Out:
#        Unnamed: 1
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
uk_public.isnull().sum()
# Out:
# £ million        0
# Unnamed: 1      74
# 2017 to 2018     0
# 2018 to 2019     0
# 2019 to 2020     0
# 2020 to 2021     0
# 2021 to 2022     0
# 2022 to 2023     0
# dtype: int64

# %%
uk_public.dropna(inplace=True)
uk_public.isnull().sum()
# Out:
# £ million       0
# Unnamed: 1      0
# 2017 to 2018    0
# 2018 to 2019    0
# 2019 to 2020    0
# 2020 to 2021    0
# 2021 to 2022    0
# 2022 to 2023    0
# dtype: int64

# %%
usa_cpi = pd.read_csv('/content/USA CPI .csv')
usa_cpi.head()
# Out:
#   Consumer Price Index item  2018  2019  2020  2021  2022  2023
# 0                  All food   1.4   1.9   3.4   3.9   9.9   5.8
# 1       Food away from home   2.6   3.1   3.4   4.5   7.7   7.1
# 2              Food at home   0.4   0.9   3.5   3.5  11.4   5.0
# 3  Meats, poultry, and fish   0.7   1.0   6.3   6.8   9.6   2.0
# 4                    Meats    0.4   1.3   7.4   7.7   8.2   2.1

# %%
usa_cpi.shape
# Out:
# (22, 7)

# %%
usa_cpi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Consumer Price Index item  22 non-null     object
#  1   2018                       22 non-null     float64
#  2   2019                       22 non-null     float64
#  3   2020                       22 non-null     float64
#  4   2021                       22 non-null     float64
#  5   2022                       22 non-null     float64
#  6   2023                       22 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 1.3+ KB

# %%
usa_cpi.describe()
# Out:
#             2018       2019       2020       2021       2022       2023
# count  22.000000  22.000000  22.000000  22.000000  22.000000  22.000000
# mean    1.050000   0.663636   3.768182   4.295455  11.427273   4.104545
# std     2.325378   2.629964   2.298941   2.211330   5.527781   3.094769
# min    -0.600000 -10.000000  -0.800000   1.100000   5.300000  -1.200000
# 25%     0.100000   0.900000   2.725000   2.900000   8.275000   1.550000
# 50%     0.400000   1.050000   3.450000   3.700000  10.150000   3.800000
# 75%     1.100000   1.600000   4.400000   5.325000  12.525000   6.900000
# max    10.800000   3.800000   9.600000   9.300000  32.200000   9.000000

# %%
usa_cpi.isnull().sum()
# Out:
# Consumer Price Index item    0
# 2018                         0
# 2019                         0
# 2020                         0
# 2021                         0
# 2022                         0
# 2023                         0
# dtype: int64

# %%
uk_gva = pd.read_csv('/content/UK Clean Gross VALue Added.csv')
uk_gva.head()
# Out:
#                           Unnamed: 0  Jan to Mar 2018  Apr to Jun 2018  \
# 0                     All industries             97.3             98.4
# 1  Agriculture, Forestry and fishing             80.5             80.9
# 2        Total production industries             97.4             98.9
# 3                 Mining & quarrying             84.7             93.3
# 4                      Manufacturing             98.7            100.3
#
#    Jul to Sep 2018  Oct to Dec 2018  Jan to Mar 2019  Apr to Jun 2019  \
# 0             98.5             99.0            100.0             99.5
# 1             84.1             89.3             99.4             98.8
# 2             98.0             97.3             97.7             98.1
# 3             97.2             99.3            102.1             99.6
# 4             99.2             98.5             98.9             98.2
#
#    Jul to Sep 2019  Oct to Dec 2019  Jan to Mar 2020  Apr to Jun 2020  \
# ...

# %%
uk_gva.shape
# Out:
# (23, 20)

# %%
uk_gva.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       23 non-null     object
#  1   Jan to Mar 2018  23 non-null     float64
#  2   Apr to Jun 2018  23 non-null     float64
#  3   Jul to Sep 2018  23 non-null     float64
#  4   Oct to Dec 2018  23 non-null     float64
#  5   Jan to Mar 2019  23 non-null     float64
#  6   Apr to Jun 2019  23 non-null     float64
#  7   Jul to Sep 2019  23 non-null     float64
#  8   Oct to Dec 2019  23 non-null     float64
#  9   Jan to Mar 2020  23 non-null     float64
#  10  Apr to Jun 2020  23 non-null     float64
#  11  Jul to Sep 2020  23 non-null     float64
#  12  Oct to Dec 2020  23 non-null     float64
#  13  Jan to Mar 2021  23 non-null     float64
#  14  Apr to Jun 2021  23 non-null     float64
#  15  Jul to Sep 2021  23 non-null     float64
# ...

# %%
uk_gva.describe()
# Out:
#        Jan to Mar 2018  Apr to Jun 2018  Jul to Sep 2018  Oct to Dec 2018  \
# count        23.000000        23.000000        23.000000        23.000000
# mean         95.513043        96.913043        97.347826        97.917391
# std           6.133611         5.844057         4.404117         3.517185
# min          80.500000        80.900000        84.100000        87.100000
# 25%          92.800000        94.250000        96.300000        97.450000
# 50%          97.400000        98.400000        98.500000        99.000000
# 75%          98.700000       100.350000       100.000000        99.500000
# max         105.100000       104.700000       102.000000       102.900000
#
#        Jan to Mar 2019  Apr to Jun 2019  Jul to Sep 2019  Oct to Dec 2019  \
# count        23.000000        23.000000        23.000000        23.000000
# mean         99.586957        99.300000       100.300000       100.808696
# std           2.895813         1.254447         1.001363         3.462909
# ...

# %%
uk_gva.isnull().sum()
# Out:
# Unnamed: 0         0
# Jan to Mar 2018    0
# Apr to Jun 2018    0
# Jul to Sep 2018    0
# Oct to Dec 2018    0
# Jan to Mar 2019    0
# Apr to Jun 2019    0
# Jul to Sep 2019    0
# Oct to Dec 2019    0
# Jan to Mar 2020    0
# Apr to Jun 2020    0
# Jul to Sep 2020    0
# Oct to Dec 2020    0
# Jan to Mar 2021    0
# Apr to Jun 2021    0
# Jul to Sep 2021    0
# Oct to Dec 2021    0
# Jan to Mar 2022    0
# Apr to Jun 2022    0
# Jul to Sep 2022    0
# dtype: int64
