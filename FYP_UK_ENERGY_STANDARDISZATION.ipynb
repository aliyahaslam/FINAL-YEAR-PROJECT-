# %% [markdown]
# <a href="https://colab.research.google.com/github/aliyahaslam/FINAL-YEAR-PROJECT-/blob/main/FYP_UK_ENERGY_STANDARDISZATION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
electricity = pd.read_csv('/content/drive/MyDrive/UK Energy Dataset/UK Energy Clean Data/UK CLEAN Electricity production.csv')

# %%
population = pd.read_csv('/content/drive/MyDrive/ONS population.csv')

# %%
population.head()
# Out:
#    Year  Population
# 0  2017     65966000
# 1  2018     66288900
# 2  2019     66630700
# 3  2020     66744100
# 4  2021     66983500

# %%
electricity.columns
# Out:
# Index(['Primary or secondary electricity', 'Generator type', 'Technology',
#        '2018', '2019', '2020', '2021', '2022', '2023'],
#       dtype='object')

# %%
electricity.head()
# Out:
#   Primary or secondary electricity         Generator type         Technology  \
# 0              Primary electricity  Major power producers              Total
# 1              Primary electricity  Major power producers            Nuclear
# 2              Primary electricity  Major power producers  Large scale hydro
# 3              Primary electricity  Major power producers  Small scale hydro
# 4              Primary electricity  Major power producers     Wind and solar
#
#       2018     2019     2020     2021     2022     2023
# 0  120,318  119,308  125,885  111,626  127,679  123,070
# 1   65,064   56,184   50,239   46,104   47,400   40,596
# 2    3,461    3,839    5,007    3,736    3,916    3,812
# 3      339      351        0        0        0        0
# 4   51,454   58,934   70,639   61,786   76,362   78,662

# %%
electricity_list = electricity.melt(id_vars=["Primary or secondary electricity", "Generator type", "Technology"], var_name = "Year", value_name="Electricity Production (GWh()" )

# %%
electricity_list["Year"] = pd.to_numeric(electricity_list["Year"])

# %%
electricity_list.head()
# Out:
#   Primary or secondary electricity         Generator type         Technology  \
# 0              Primary electricity  Major power producers              Total
# 1              Primary electricity  Major power producers            Nuclear
# 2              Primary electricity  Major power producers  Large scale hydro
# 3              Primary electricity  Major power producers  Small scale hydro
# 4              Primary electricity  Major power producers     Wind and solar
#
#    Year Electricity Production (GWh()
# 0  2018                       120,318
# 1  2018                        65,064
# 2  2018                         3,461
# 3  2018                           339
# 4  2018                        51,454

# %%
electricity_list = electricity_list.merge(population, on="Year", how="left")

# %%
electricity_list.head()
# Out:
#   Primary or secondary electricity         Generator type         Technology  \
# 0              Primary electricity  Major power producers              Total
# 1              Primary electricity  Major power producers            Nuclear
# 2              Primary electricity  Major power producers  Large scale hydro
# 3              Primary electricity  Major power producers  Small scale hydro
# 4              Primary electricity  Major power producers     Wind and solar
#
#    Year Electricity Production (GWh()  Population
# 0  2018                       120,318     66288900
# 1  2018                        65,064     66288900
# 2  2018                         3,461     66288900
# 3  2018                           339     66288900
# 4  2018                        51,454     66288900

# %%
electricity_list.rename(columns={"Electricity Production (GWh()": "Electricity Production (GWh)"}, inplace=True)

# %%
electricity_list["Electricity Production (GWh)"] = (
    electricity_list["Electricity Production (GWh)"].str.replace(",", "").astype(float)
)

# %%
electricity_list["Electricity Production per Capita"] = (electricity_list["Electricity Production (GWh)"] * 1000) / electricity_list["Population "]

# %%
electricity_list
# Out:
#     Primary or secondary electricity         Generator type  \
# 0                Primary electricity  Major power producers
# 1                Primary electricity  Major power producers
# 2                Primary electricity  Major power producers
# 3                Primary electricity  Major power producers
# 4                Primary electricity  Major power producers
# ..                               ...                    ...
# 181                 Total production                  Total
# 182                 Total production                  Total
# 183                 Total production                  Total
# 184                 Total production                  Total
# 185                 Total production                  Total
#
#             Technology  Year  Electricity Production (GWh)  Population   \
# 0                Total  2018                      120318.0     66288900
# 1              Nuclear  2018                       65064.0     66288900
# 2    Large scale hydro  2018                        3461.0     66288900
# 3    Small scale hydro  2018                         339.0     66288900
# 4       Wind and solar  2018                       51454.0     66288900
# ..                 ...   ...                           ...          ...
# 181                Oil  2023                        1875.0     68265200
# 182                Gas  2023                      101659.0     68265200
# 183          Bioenergy  2023                       34086.0     68265200
# 184        Other fuels  2023                        6107.0     68265200
# 185                All  2023                      289841.0     68265200
#
#      Electricity Production per Capita
# 0                             1.815055
# 1                             0.981522
# 2                             0.052211
# 3                             0.005114
# 4                             0.776208
# ..                                 ...
# 181                           0.027466
# 182                           1.489178
# 183                           0.499317
# 184                           0.089460
# 185                           4.245809
#
# [186 rows x 7 columns]

# %%
electricity_list.to_csv("Electricity Production per Capita.csv", index=False)
